# %%
# !pip install librosa pandas scikit-learn joblib tqdm
# Out:
# Requirement already satisfied: librosa in f:\projects\github projects\dimentia ai\env\lib\site-packages (0.11.0)
# Requirement already satisfied: pandas in f:\projects\github projects\dimentia ai\env\lib\site-packages (2.3.3)
# Requirement already satisfied: scikit-learn in f:\projects\github projects\dimentia ai\env\lib\site-packages (1.7.2)
# Requirement already satisfied: joblib in f:\projects\github projects\dimentia ai\env\lib\site-packages (1.5.2)
# Requirement already satisfied: tqdm in f:\projects\github projects\dimentia ai\env\lib\site-packages (4.67.1)
# Requirement already satisfied: audioread>=2.1.9 in f:\projects\github projects\dimentia ai\env\lib\site-packages (from librosa) (3.1.0)
# Requirement already satisfied: numba>=0.51.0 in f:\projects\github projects\dimentia ai\env\lib\site-packages (from librosa) (0.62.1)
# Requirement already satisfied: numpy>=1.22.3 in f:\projects\github projects\dimentia ai\env\lib\site-packages (from librosa) (2.3.5)
# Requirement already satisfied: scipy>=1.6.0 in f:\projects\github projects\dimentia ai\env\lib\site-packages (from librosa) (1.16.3)
# Requirement already satisfied: decorator>=4.3.0 in f:\projects\github projects\dimentia ai\env\lib\site-packages (from librosa) (5.2.1)
# Requirement already satisfied: soundfile>=0.12.1 in f:\projects\github projects\dimentia ai\env\lib\site-packages (from librosa) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in f:\projects\github projects\dimentia ai\env\lib\site-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in f:\projects\github projects\dimentia ai\env\lib\site-packages (from librosa) (1.0.0)
# Requirement already satisfied: typing_extensions>=4.1.1 in f:\projects\github projects\dimentia ai\env\lib\site-packages (from librosa) (4.15.0)
# Requirement already satisfied: lazy_loader>=0.1 in f:\projects\github projects\dimentia ai\env\lib\site-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in f:\projects\github projects\dimentia ai\env\lib\site-packages (from librosa) (1.1.2)
# Requirement already satisfied: standard-aifc in f:\projects\github projects\dimentia ai\env\lib\site-packages (from librosa) (3.13.0)
# Requirement already satisfied: standard-sunau in f:\projects\github projects\dimentia ai\env\lib\site-packages (from librosa) (3.13.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in f:\projects\github projects\dimentia ai\env\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in f:\projects\github projects\dimentia ai\env\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in f:\projects\github projects\dimentia ai\env\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in f:\projects\github projects\dimentia ai\env\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: colorama in f:\projects\github projects\dimentia ai\env\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: packaging in f:\projects\github projects\dimentia ai\env\lib\site-packages (from lazy_loader>=0.1->librosa) (25.0)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in f:\projects\github projects\dimentia ai\env\lib\site-packages (from numba>=0.51.0->librosa) (0.45.1)
# Requirement already satisfied: platformdirs>=2.5.0 in f:\projects\github projects\dimentia ai\env\lib\site-packages (from pooch>=1.1->librosa) (4.5.0)
# Requirement already satisfied: requests>=2.19.0 in f:\projects\github projects\dimentia ai\env\lib\site-packages (from pooch>=1.1->librosa) (2.32.5)
# Requirement already satisfied: six>=1.5 in f:\projects\github projects\dimentia ai\env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in f:\projects\github projects\dimentia ai\env\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in f:\projects\github projects\dimentia ai\env\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in f:\projects\github projects\dimentia ai\env\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in f:\projects\github projects\dimentia ai\env\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2025.11.12)
# Requirement already satisfied: cffi>=1.0 in f:\projects\github projects\dimentia ai\env\lib\site-packages (from soundfile>=0.12.1->librosa) (2.0.0)
# Requirement already satisfied: pycparser in f:\projects\github projects\dimentia ai\env\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.23)
# Requirement already satisfied: standard-chunk in f:\projects\github projects\dimentia ai\env\lib\site-packages (from standard-aifc->librosa) (3.13.0)
# Requirement already satisfied: audioop-lts in f:\projects\github projects\dimentia ai\env\lib\site-packages (from standard-aifc->librosa) (0.2.2)

# %%
import os
import librosa
import numpy as np
import pandas as pd
from tqdm import tqdm
import joblib
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

DATA_ROOT = "../dataset/Pitt"  # <-- change if needed

# %%
def get_label_from_folder(folder_name):
    folder = folder_name.lower()
    if "control" in folder:
        return 0
    if "dementia" in folder:
        return 2
    return None

# %%
def extract_patient_text(cha_path, tag="*PAR:"):
    text_lines = []
    with open(cha_path, "r", encoding="utf-8", errors="ignore") as f:
        for line in f:
            line = line.strip()
            if line.startswith(tag):
                if "\t" in line:
                    content = line.split("\t", 1)[1]
                else:
                    content = line[len(tag):]
                text_lines.append(content)

    return " ".join(text_lines).lower()

# %%
def extract_text_features(text):
    words = text.split()
    length = len(words)
    avg_len = sum(len(w) for w in words) / length if length else 0
    unique_ratio = len(set(words)) / length if length else 0
    return np.array([length, avg_len, unique_ratio])

# %%
def extract_audio_features(audio_path, sr_target=16000):
    y, sr = librosa.load(audio_path, sr=sr_target)

    mfcc = np.mean(librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13), axis=1)
    chroma = np.mean(librosa.feature.chroma_stft(y=y, sr=sr), axis=1)
    zcr = np.mean(librosa.feature.zero_crossing_rate(y))
    centroid = np.mean(librosa.feature.spectral_centroid(y=y, sr=sr))
    tempo, _ = librosa.beat.beat_track(y=y, sr=sr)

    return np.hstack([mfcc, chroma, zcr, centroid, tempo])

# %%
features = []
labels = []

for folder in ["Control", "Dementia"]:
    folder_path = os.path.join(DATA_ROOT, folder)
    label = get_label_from_folder(folder)

    for file in tqdm(os.listdir(folder_path), desc=f"Processing {folder}"):
        if file.endswith(".cha"):
            cha_path = os.path.join(folder_path, file)
            wav_path = os.path.join(folder_path, file.replace(".cha", ".wav"))

            if not os.path.exists(wav_path):
                continue

            # Text features
            text = extract_patient_text(cha_path)
            text_feat = extract_text_features(text)

            # Audio features
            audio_feat = extract_audio_features(wav_path)

            combined = np.hstack([audio_feat, text_feat])
            features.append(combined)
            labels.append(label)
# Out:
# Processing Control: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 49344.75it/s]
# Processing Dementia: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 51781.53it/s]

# %%
X = np.array(features)
y = np.array(labels)

X.shape, y.shape
# Out:
# ((0,), (0,))

# %%
import os

print("CWD =", os.getcwd())
print("DATA_ROOT exists:", os.path.exists(DATA_ROOT))
print("Folders inside DATA_ROOT:", os.listdir(DATA_ROOT))
# Out:
# CWD = F:\Projects\github projects\dimentia ai\notebooks
# DATA_ROOT exists: True
# Folders inside DATA_ROOT: ['0metadata.cdc', 'Control', 'Dementia']

# %%
import os

control_cookie = os.path.join(DATA_ROOT, "Control", "cookie")
print("Path:", control_cookie)
print("Exists:", os.path.exists(control_cookie))
print("Files:", os.listdir(control_cookie)[:20])
# Out:
# Path: ../dataset/Pitt\Control\cookie
# Exists: True
# Files: ['002-0.cha', '002-1.cha', '002-2.cha', '002-3.cha', '006-2.cha', '006-3.cha', '006-4.cha', '013-0.cha', '013-2.cha', '013-3.cha', '013-4.cha', '015-0.cha', '015-1.cha', '015-2.cha', '015-3.cha', '015-4.cha', '017-4.cha', '021-0.cha', '021-1.cha', '021-2.cha']
